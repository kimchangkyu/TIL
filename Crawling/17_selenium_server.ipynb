# %%
from selenium import webdriver
from PIL import Image as pil

# %%
options = webdriver.ChromeOptions()
options.add_argument("headless")
options.add_argument("window-size=1920x1080")
driver = webdriver.Chrome(options=options)

# %% [markdown]
# `ps -e | grep brow`로 브라우저를 확인 가능

# %%
driver.get("https://naver.com")
driver.save_screenshot("naver_main.png")
driver.quit()

# %% [markdown]
# ### 저장한 이미지 확인

# %%
pil_im = pil.open("naver_main.png")
pil_im # 한글이 깨진것을 확인
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080 at 0x7F9FD658DA58>

# %%
options = webdriver.ChromeOptions()
options.add_argument("headless")
options.add_argument("window-size=1920x1080")
driver = webdriver.Chrome(options=options)

# %%
driver.get("https://naver.com")
driver.save_screenshot("naver_main.png")
driver.quit()

# %%
pil_im = pil.open("naver_main.png")
pil_im # 한글폰트 설치 후 한글이 나온 것을 확인
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080 at 0x7F9FD6481128>
